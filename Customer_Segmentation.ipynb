# %%
import pandas as pd
import datetime
import numpy as np

# %%
# Create data frame from file
df = pd.read_csv('/home/trungdung/Downloads/Data_Final.csv')
df["Date_Time"] = pd.to_datetime(df["Date_Time"], format="%Y-%m-%d %H:%M:%S")
df["Week"] = df["Date_Time"].dt.week
# df = df.sort_values(by='Date_Time')
# df.groupby('Mild')["Unit_sales"].sum()

# %%
def sales_share(col_name, data_frame):
    """
    Calculate sales shares for each value in col_name of data_frame by week
    :param col_name: column name    
    :param data_frame: input data frame
    :return data frame, index = week, data = sale shares
    """
    group = data_frame.groupby(['Week',col_name])['Unit_sales'].sum()
    g = pd.DataFrame(group).reset_index().pivot('Week', col_name).fillna(0)
    g = g.div(g.sum(axis=1), axis=0)
    return g

item_sale_share = sales_share("Brand", df)
item_sale_share
# Out:
#       Unit_sales
# Brand MainStream     Niche
# Week
# 10      0.714286  0.285714
# 11      0.729167  0.270833
# 12      0.507937  0.492063
# 13      0.842593  0.157407

# %%
def attribute_sim_df(attribute_name, data_frame):
    """
    Calculate similarity of each pair value in attribute_name
    of data_frame based on sales shares
    :param attribute_name: name of attribute/column to calculate similarity
    :param data_frame: input data frame
    :return: data frame, index and column = unique values in attribute_name column
                         data = similarities     
    """
    g = sales_share(attribute_name,data_frame)
    col_index = g.columns.get_level_values(1).tolist()

    #  If an attribute has more than 2 values, similarity = correlation coefficient
    #  else similarity = 2 * standard deviation (because correlation = -1)    
    if(len(col_index) > 2):  # more than 2 attribute values
        attribute_corr = pd.DataFrame(
            np.corrcoef(g.transpose()),
            columns=col_index,
            index=col_index
        )
    elif len(col_index) == 2:  # exactly 2 attribite values
        att_val_sim = 2 * np.std(g,axis=0).tolist()[0]
        attribute_corr = pd.DataFrame(
            np.array([[1, att_val_sim], [att_val_sim, 1]]),
            columns=col_index,
            index=col_index
        )
    else:  # 1 attribite value
        attribute_corr = pd.DataFrame(data=[1], columns=col_index, index=col_index)
    return attribute_corr

item_sim = attribute_sim_df("Item_ID", df)
item_sim
# Out:
#           Yo000     Yo001     Yo002     Yo003     Yo004     Yo005     Yo006  \
# Yo000  1.000000 -0.889140 -0.321650  0.607633 -0.399842  0.452544  0.328531
# Yo001 -0.889140  1.000000  0.207374 -0.879208  0.329386  0.005708 -0.471205
# Yo002 -0.321650  0.207374  1.000000  0.198840 -0.713396 -0.304701  0.761970
# Yo003  0.607633 -0.879208  0.198840  1.000000 -0.463035 -0.387284  0.736002
# Yo004 -0.399842  0.329386 -0.713396 -0.463035  1.000000 -0.226014 -0.895382
# Yo005  0.452544  0.005708 -0.304701 -0.387284 -0.226014  1.000000 -0.205791
# Yo006  0.328531 -0.471205  0.761970  0.736002 -0.895382 -0.205791  1.000000
# Yo007 -0.358216 -0.065115  0.642015  0.521077 -0.184979 -0.912230  0.563744
# Yo008 -0.390496  0.730258  0.338696 -0.747278 -0.242279  0.567226 -0.126392
# Yo009 -0.114709  0.138081 -0.898730 -0.412112  0.947260  0.024737 -0.919778
#
#           Yo007     Yo008     Yo009
# Yo000 -0.358216 -0.390496 -0.114709
# Yo001 -0.065115  0.730258  0.138081
# Yo002  0.642015  0.338696 -0.898730
# Yo003  0.521077 -0.747278 -0.412112
# Yo004 -0.184979 -0.242279  0.947260
# Yo005 -0.912230  0.567226  0.024737
# Yo006  0.563744 -0.126392 -0.919778
# Yo007  1.000000 -0.404200 -0.432106
# Yo008 -0.404200  1.000000 -0.268747
# Yo009 -0.432106 -0.268747  1.000000

# %%
def post_process_sim_val(sim_val):
    """
    post-process similarity value
    :param sim_val: input similarity value
    """
    t_sim = sim_val
    if t_sim < 0.99:
        t_sim = max(0, -t_sim)
    return t_sim
        
def post_process_sim(sim_df):
    """
    Post-process similarity (convert similarity to dissimilarity)
    :param sim_df: similarity data frame of item/attribute
    :return: Post-processed similarity data frame
    """
    n_col = sim_df.shape[0]
    # In case of binary attribute values, nothing to change 
    if n_col > 2:
        return sim_df.applymap(post_process_sim_val)
    else:
        return sim_df

post_process_sim(item_sim)
# Out:
#           Yo000     Yo001     Yo002     Yo003     Yo004     Yo005     Yo006  \
# Yo000  1.000000  0.889140  0.321650  0.000000  0.399842  0.000000  0.000000
# Yo001  0.889140  1.000000  0.000000  0.879208  0.000000  0.000000  0.471205
# Yo002  0.321650  0.000000  1.000000  0.000000  0.713396  0.304701  0.000000
# Yo003  0.000000  0.879208  0.000000  1.000000  0.463035  0.387284  0.000000
# Yo004  0.399842  0.000000  0.713396  0.463035  1.000000  0.226014  0.895382
# Yo005  0.000000  0.000000  0.304701  0.387284  0.226014  1.000000  0.205791
# Yo006  0.000000  0.471205  0.000000  0.000000  0.895382  0.205791  1.000000
# Yo007  0.358216  0.065115  0.000000  0.000000  0.184979  0.912230  0.000000
# Yo008  0.390496  0.000000  0.000000  0.747278  0.242279  0.000000  0.126392
# Yo009  0.114709  0.000000  0.898730  0.412112  0.000000  0.000000  0.919778
#
#           Yo007     Yo008     Yo009
# Yo000  0.358216  0.390496  0.114709
# Yo001  0.065115  0.000000  0.000000
# Yo002  0.000000  0.000000  0.898730
# Yo003  0.000000  0.747278  0.412112
# Yo004  0.184979  0.242279  0.000000
# Yo005  0.912230  0.000000  0.000000
# Yo006  0.000000  0.126392  0.919778
# Yo007  1.000000  0.404200  0.432106
# Yo008  0.404200  1.000000  0.268747
# Yo009  0.432106  0.268747  1.000000

# %%
def attribute_item_sim(attribute_name, data_frame):
    """
    Calculate item-attribute similarity
    :param attribute_name: attribute to calculate with "Item_ID"
    :param data_frame: input data frame
    :return: item-attribute similarity 
    """
    item_sim = []
    attribute_sim = []
    
    # post-process-similarity
    # calculate item-item similarity
    item_corr = post_process_sim(attribute_sim_df('Item_ID', data_frame))
    
    # calculate attribute-values similarity
    attribute_corr = post_process_sim(attribute_sim_df(attribute_name, data_frame))
    
    # create data frame to define item_ID and it attribute value
    table_attribute_item = data_frame.loc[:,['Item_ID',attribute_name]]
    table_attribute_item = table_attribute_item.groupby('Item_ID').max()
    
    len_item_ids = table_attribute_item.shape[0]  # number of Item_ID
    
    # prepare table item similarity and attribute value similarity
    # for each pair of item (including the same), append their similarity to array item_sim
    # then find and put their attribute value similarity to array attribute_sim
    for i in range(len_item_ids):
        item_id_i = table_attribute_item.index.tolist()[i]
        attribute_i = table_attribute_item.iloc[:,0].tolist()[i]
        for j in range(i, len_item_ids):
            # operate with item-item similarity
            item_id_j = table_attribute_item.index.tolist()[j]
            item_sim_val = item_corr.at[item_id_i, item_id_j]
            item_sim.append(item_sim_val)
            # find and add relevant attribute value similarity
            attribute_j = table_attribute_item.iloc[:,0].tolist()[j]
            attribute_sim_val = attribute_corr.at[attribute_i,attribute_j]
            attribute_sim.append(attribute_sim_val)
    
    #  in case there's only one item or attribute value
    if (len(set(item_sim)) == 1) or (len(set(attribute_sim)) == 1):
        return 1.0
    else:
        return np.corrcoef([item_sim, attribute_sim])[0, 1]

# %%
print("Size :" ,attribute_item_sim('Size', df))
print("Organic :" ,attribute_item_sim('Organic', df))
print("Brand :" ,attribute_item_sim('Brand', df))
print("Mild :" ,attribute_item_sim('Mild', df))
print("Flavor :" ,attribute_item_sim('Flavor', df))
# Out:
# Size : 0.38255673972922344
# Organic : 0.26198126747036
# Brand : 0.062374235302752545
# Mild : 0.4897732545474556
# Flavor : 0.34491652526130007

# %%
# Item-Mild is max ==> most significant attribute is "Mild", values of which is "Mild" & "Non-mild"
df.groupby('Mild')['Unit_sales'].sum()
# Out:
# Mild
# Mild        254
# Non-mild    132
# Name: Unit_sales, dtype: int64

# %%
df_mild = df.loc[df['Mild'] == 'Mild']
df_mild
# Out:
#               Date_Time  Store_ID  User_ID Item_ID  Unit_sales Category  \
# 0   2018-03-10 06:00:00         1       11   Yo008           4   Yogurt
# 1   2018-03-21 06:00:00         1       12   Yo008           3   Yogurt
# 3   2018-03-10 06:00:00         1        7   Yo004           3   Yogurt
# 6   2018-03-24 06:00:00         1       12   Yo006           2   Yogurt
# 7   2018-03-28 06:00:00         1        1   Yo003           1   Yogurt
# 12  2018-03-14 06:00:00         1        7   Yo004           5   Yogurt
# 13  2018-03-21 06:00:00         1        3   Yo000           4   Yogurt
# 14  2018-03-28 06:00:00         1       19   Yo008           4   Yogurt
# 15  2018-03-24 06:00:00         1       19   Yo003           3   Yogurt
# 17  2018-03-31 06:00:00         1        8   Yo006           5   Yogurt
# 18  2018-03-21 06:00:00         1        5   Yo003           1   Yogurt
# 19  2018-03-07 06:00:00         2        1   Yo006           1   Yogurt
# 20  2018-03-31 06:00:00         1        2   Yo004           2   Yogurt
# 22  2018-03-31 06:00:00         1        2   Yo004           3   Yogurt
# 23  2018-03-14 06:00:00         1        7   Yo008           1   Yogurt
# 25  2018-03-31 06:00:00         1       15   Yo003           4   Yogurt
# 26  2018-03-21 06:00:00         1       17   Yo003           1   Yogurt
# 27  2018-03-17 06:00:00         1        7   Yo003           1   Yogurt
# 28  2018-03-31 06:00:00         1       14   Yo006           5   Yogurt
# 29  2018-03-07 06:00:00         2       14   Yo008           4   Yogurt
# 30  2018-03-21 06:00:00         1        1   Yo008           4   Yogurt
# 31  2018-03-14 06:00:00         1       20   Yo003           5   Yogurt
# 32  2018-03-07 06:00:00         1        7   Yo004           4   Yogurt
# 33  2018-03-10 06:00:00         1       15   Yo001           3   Yogurt
# 34  2018-03-14 06:00:00         1       13   Yo000           4   Yogurt
# 20   Medium      Organic  MainStream  Mild  Non-flavored    13
# 22   Medium      Organic  MainStream  Mild  Non-flavored    13
# 23    Large      Organic  MainStream  Mild       Special    11
# 25    Small  Non-organic       Niche  Mild       Special    13
# 26    Small  Non-organic       Niche  Mild       Special    12
# 27    Small  Non-organic       Niche  Mild       Special    11
# 28   Medium      Organic       Niche  Mild    MainStream    13
# 29    Large      Organic  MainStream  Mild       Special    10
# 30    Large      Organic  MainStream  Mild       Special    12
# 31    Small  Non-organic       Niche  Mild       Special    11
# 32   Medium      Organic  MainStream  Mild  Non-flavored    10
# 33    Small      Organic  MainStream  Mild    MainStream    10
# 34    Large      Organic       Niche  Mild  Non-flavored    11
# 35    Large      Organic       Niche  Mild  Non-flavored    11
# 36   Medium      Organic       Niche  Mild    MainStream    11
# 37   Medium      Organic  MainStream  Mild  Non-flavored    11
# 38    Large      Organic  MainStream  Mild       Special    10
# 39   Medium      Organic  MainStream  Mild  Non-flavored    10
# ..      ...          ...         ...   ...           ...   ...
# 85   Medium      Organic       Niche  Mild    MainStream    11
# 86   Medium      Organic       Niche  Mild    MainStream    10
# 87    Large      Organic       Niche  Mild  Non-flavored    12
# 88    Small      Organic  MainStream  Mild    MainStream    13
# 89   Medium      Organic  MainStream  Mild  Non-flavored    11
# 90   Medium      Organic  MainStream  Mild  Non-flavored    13
# 92   Medium      Organic       Niche  Mild    MainStream    10
# 93   Medium      Organic  MainStream  Mild  Non-flavored    11
# 94   Medium      Organic  MainStream  Mild  Non-flavored    13
# 95    Large      Organic       Niche  Mild  Non-flavored    11
# 99    Small      Organic  MainStream  Mild    MainStream    13
# 100   Small  Non-organic       Niche  Mild       Special    12
# 104   Large      Organic  MainStream  Mild       Special    13
# 105   Large      Organic  MainStream  Mild       Special    13
# 107   Large      Organic  MainStream  Mild       Special    13
# 108  Medium      Organic       Niche  Mild    MainStream    12
# 110  Medium      Organic  MainStream  Mild  Non-flavored    11
# 111   Small      Organic  MainStream  Mild    MainStream    13
# 116   Small  Non-organic       Niche  Mild       Special    10
# 118   Small  Non-organic       Niche  Mild       Special    10
# 119   Large      Organic  MainStream  Mild       Special    11
# 121   Small  Non-organic       Niche  Mild       Special    12
# 122  Medium      Organic  MainStream  Mild  Non-flavored    11
# 123   Small  Non-organic       Niche  Mild       Special    10
# 124   Small  Non-organic       Niche  Mild       Special    11
# 125   Large      Organic       Niche  Mild  Non-flavored    12
# 127   Small      Organic  MainStream  Mild    MainStream    11
# 128   Large      Organic  MainStream  Mild       Special    10
# 129   Small      Organic  MainStream  Mild    MainStream    10
# 130   Small      Organic  MainStream  Mild    MainStream    10
#
# [88 rows x 12 columns]

# %%
print("Size :" ,attribute_item_sim('Size', df_mild))
print("Organic :" ,attribute_item_sim('Organic', df_mild))
print("Brand :" ,attribute_item_sim('Brand', df_mild))
print("Flavor :" ,attribute_item_sim('Flavor', df_mild))
# Out:
# Size : 0.6043098264883451
# Organic : 0.19203978215362547
# Brand : -0.018570923182703886
# Flavor : 0.5712849172745973

# %%
# In Mild sub-section, Item-Size similarity is max ==> 
# ==> most significant attribute in this subsection is Size
df_mild.groupby('Size')['Unit_sales'].sum()
# Out:
# Size
# Large     75
# Medium    92
# Small     87
# Name: Unit_sales, dtype: int64

# %%
df_mild_large = df_mild.loc[df_mild['Size'] == "Large"]
df_mild_large
# Out:
#               Date_Time  Store_ID  User_ID Item_ID  Unit_sales Category  \
#
# 104  Large  Organic  MainStream  Mild       Special    13
# 105  Large  Organic  MainStream  Mild       Special    13
# 107  Large  Organic  MainStream  Mild       Special    13
# 119  Large  Organic  MainStream  Mild       Special    11
# 125  Large  Organic       Niche  Mild  Non-flavored    12
# 128  Large  Organic  MainStream  Mild       Special    10

# %%
print("Organic :" ,attribute_item_sim('Organic', df_mild_large))
print("Brand :" ,attribute_item_sim('Brand', df_mild_large))
print("Flavor :" ,attribute_item_sim('Flavor', df_mild_large))

# In sub-section Mild_Large item-attribute = 1
# ==> There no significant attribute
# sub-section Mild_Large is a leaf node
# as we can see, there are two type of item, each with their attribute values
# Out:
# Organic : 1.0
# Brand : 0.9999999999999998
# Flavor : 0.9999999999999998

# %%
df_mild_medium = df_mild.loc[df_mild['Size'] == "Medium"]
df_mild_medium
# Out:
#               Date_Time  Store_ID  User_ID Item_ID  Unit_sales Category  \
# 3   2018-03-10 06:00:00         1        7   Yo004           3   Yogurt
# 6   2018-03-24 06:00:00         1       12   Yo006           2   Yogurt
# 12  2018-03-14 06:00:00         1        7   Yo004           5   Yogurt
# 17  2018-03-31 06:00:00         1        8   Yo006           5   Yogurt
# 19  2018-03-07 06:00:00         2        1   Yo006           1   Yogurt
# 20  2018-03-31 06:00:00         1        2   Yo004           2   Yogurt
# 22  2018-03-31 06:00:00         1        2   Yo004           3   Yogurt
# 28  2018-03-31 06:00:00         1       14   Yo006           5   Yogurt
# 32  2018-03-07 06:00:00         1        7   Yo004           4   Yogurt
# 36  2018-03-17 06:00:00         1       14   Yo006           3   Yogurt
# 37  2018-03-14 06:00:00         1       11   Yo004           1   Yogurt
# 39  2018-03-07 06:00:00         1        7   Yo004           4   Yogurt
# 40  2018-03-10 06:00:00         1        3   Yo004           3   Yogurt
# 51  2018-03-07 06:00:00         1       18   Yo006           3   Yogurt
# 56  2018-03-21 06:00:00         2       13   Yo004           4   Yogurt
# 57  2018-03-07 06:00:00         1       14   Yo006           1   Yogurt
# 62  2018-03-10 06:00:00         1        2   Yo006           2   Yogurt
# 63  2018-03-31 06:00:00         1        9   Yo004           4   Yogurt
# 64  2018-03-14 06:00:00         1       17   Yo006           2   Yogurt
# 72  2018-03-07 06:00:00         1       16   Yo006           1   Yogurt
# 76  2018-03-17 06:00:00         1        8   Yo004           5   Yogurt
# 85  2018-03-17 06:00:00         1        3   Yo006           3   Yogurt
# 86  2018-03-10 06:00:00         1        8   Yo006           1   Yogurt
# 89  2018-03-14 06:00:00         2        1   Yo004           2   Yogurt
# 90  2018-03-31 06:00:00         1       18   Yo004           2   Yogurt
# 92  2018-03-07 06:00:00         1       18   Yo006           4   Yogurt
# 93  2018-03-17 06:00:00         1       16   Yo004           5   Yogurt
# 94  2018-03-31 06:00:00         1        6   Yo004           3   Yogurt
# 108 2018-03-21 06:00:00         1       16   Yo006           5   Yogurt
# 110 2018-03-14 06:00:00         1        9   Yo004           1   Yogurt
# 122 2018-03-14 06:00:00         1       17   Yo004           3   Yogurt
#
#        Size  Organic       Brand  Mild        Flavor  Week
# 3    Medium  Organic  MainStream  Mild  Non-flavored    10
# 6    Medium  Organic       Niche  Mild    MainStream    12
# 12   Medium  Organic  MainStream  Mild  Non-flavored    11
# 17   Medium  Organic       Niche  Mild    MainStream    13
# 19   Medium  Organic       Niche  Mild    MainStream    10
# 20   Medium  Organic  MainStream  Mild  Non-flavored    13
# 22   Medium  Organic  MainStream  Mild  Non-flavored    13
# 28   Medium  Organic       Niche  Mild    MainStream    13
# 32   Medium  Organic  MainStream  Mild  Non-flavored    10
# 36   Medium  Organic       Niche  Mild    MainStream    11
# 37   Medium  Organic  MainStream  Mild  Non-flavored    11
# 39   Medium  Organic  MainStream  Mild  Non-flavored    10
# 40   Medium  Organic  MainStream  Mild  Non-flavored    10
# 51   Medium  Organic       Niche  Mild    MainStream    10
# 56   Medium  Organic  MainStream  Mild  Non-flavored    12
# 57   Medium  Organic       Niche  Mild    MainStream    10
# 62   Medium  Organic       Niche  Mild    MainStream    10
# 63   Medium  Organic  MainStream  Mild  Non-flavored    13
# 64   Medium  Organic       Niche  Mild    MainStream    11
# 72   Medium  Organic       Niche  Mild    MainStream    10
# 76   Medium  Organic  MainStream  Mild  Non-flavored    11
# 85   Medium  Organic       Niche  Mild    MainStream    11
# 86   Medium  Organic       Niche  Mild    MainStream    10
# 89   Medium  Organic  MainStream  Mild  Non-flavored    11
# 90   Medium  Organic  MainStream  Mild  Non-flavored    13
# 92   Medium  Organic       Niche  Mild    MainStream    10
# 93   Medium  Organic  MainStream  Mild  Non-flavored    11
# 94   Medium  Organic  MainStream  Mild  Non-flavored    13
# 108  Medium  Organic       Niche  Mild    MainStream    12
# 110  Medium  Organic  MainStream  Mild  Non-flavored    11
# 122  Medium  Organic  MainStream  Mild  Non-flavored    11

# %%
print("Organic :" ,attribute_item_sim('Organic', df_mild_large))
print("Brand :" ,attribute_item_sim('Brand', df_mild_medium))
print("Flavor :" ,attribute_item_sim('Flavor', df_mild_medium))

# In sub-section Mild_Medium item-attribute = 1
# ==> There no significant attribute
# sub-section Mild_Medium is a leaf node
# as we can see, there are two type of item, each with their attribute values
# Out:
# Organic : 1.0
# Brand : 1.0
# Flavor : 1.0

# %%
df_mild_small = df_mild.loc[df_mild['Size'] == "Small"]
df_mild_small
# Out:
#               Date_Time  Store_ID  User_ID Item_ID  Unit_sales Category  \
# 7   2018-03-28 06:00:00         1        1   Yo003           1   Yogurt
# 15  2018-03-24 06:00:00         1       19   Yo003           3   Yogurt
# 18  2018-03-21 06:00:00         1        5   Yo003           1   Yogurt
# 25  2018-03-31 06:00:00         1       15   Yo003           4   Yogurt
# 26  2018-03-21 06:00:00         1       17   Yo003           1   Yogurt
# 27  2018-03-17 06:00:00         1        7   Yo003           1   Yogurt
# 31  2018-03-14 06:00:00         1       20   Yo003           5   Yogurt
# 33  2018-03-10 06:00:00         1       15   Yo001           3   Yogurt
# 41  2018-03-28 06:00:00         2        6   Yo003           1   Yogurt
# 46  2018-03-10 06:00:00         1       19   Yo003           4   Yogurt
# 50  2018-03-07 06:00:00         1       12   Yo003           5   Yogurt
# 58  2018-03-21 06:00:00         1       13   Yo003           1   Yogurt
# 59  2018-03-24 06:00:00         1       19   Yo003           1   Yogurt
# 61  2018-03-28 06:00:00         2       11   Yo001           5   Yogurt
# 67  2018-03-10 06:00:00         1        2   Yo003           3   Yogurt
# 68  2018-03-28 06:00:00         1       17   Yo001           1   Yogurt
# 75  2018-03-07 06:00:00         1       16   Yo001           2   Yogurt
# 77  2018-03-14 06:00:00         1       13   Yo001           5   Yogurt
# 84  2018-03-14 06:00:00         2       20   Yo003           1   Yogurt
# 88  2018-03-28 06:00:00         1        8   Yo001           4   Yogurt
# 99  2018-03-28 06:00:00         2        7   Yo001           4   Yogurt
# 100 2018-03-24 06:00:00         2       14   Yo003           3   Yogurt
# 111 2018-03-28 06:00:00         1        5   Yo001           3   Yogurt
# 116 2018-03-07 06:00:00         2        7   Yo003           5   Yogurt
# 118 2018-03-07 06:00:00         1        8   Yo003           1   Yogurt
# 121 2018-03-24 06:00:00         1        5   Yo003           3   Yogurt
# 123 2018-03-10 06:00:00         1       15   Yo003           3   Yogurt
# 124 2018-03-14 06:00:00         1       18   Yo003           5   Yogurt
# 127 2018-03-17 06:00:00         1        1   Yo001           2   Yogurt
# 129 2018-03-07 06:00:00         1       13   Yo001           3   Yogurt
# 130 2018-03-07 06:00:00         1        1   Yo001           3   Yogurt
#
#       Size      Organic       Brand  Mild      Flavor  Week
# 7    Small  Non-organic       Niche  Mild     Special    13
# 15   Small  Non-organic       Niche  Mild     Special    12
# 18   Small  Non-organic       Niche  Mild     Special    12
# 25   Small  Non-organic       Niche  Mild     Special    13
# 26   Small  Non-organic       Niche  Mild     Special    12
# 27   Small  Non-organic       Niche  Mild     Special    11
# 31   Small  Non-organic       Niche  Mild     Special    11
# 33   Small      Organic  MainStream  Mild  MainStream    10
# 41   Small  Non-organic       Niche  Mild     Special    13
# 46   Small  Non-organic       Niche  Mild     Special    10
# 50   Small  Non-organic       Niche  Mild     Special    10
# 58   Small  Non-organic       Niche  Mild     Special    12
# 59   Small  Non-organic       Niche  Mild     Special    12
# 61   Small      Organic  MainStream  Mild  MainStream    13
# 67   Small  Non-organic       Niche  Mild     Special    10
# 68   Small      Organic  MainStream  Mild  MainStream    13
# 75   Small      Organic  MainStream  Mild  MainStream    10
# 77   Small      Organic  MainStream  Mild  MainStream    11
# 84   Small  Non-organic       Niche  Mild     Special    11
# 88   Small      Organic  MainStream  Mild  MainStream    13
# 99   Small      Organic  MainStream  Mild  MainStream    13
# 100  Small  Non-organic       Niche  Mild     Special    12
# 111  Small      Organic  MainStream  Mild  MainStream    13
# 116  Small  Non-organic       Niche  Mild     Special    10
# 118  Small  Non-organic       Niche  Mild     Special    10
# 121  Small  Non-organic       Niche  Mild     Special    12
# 123  Small  Non-organic       Niche  Mild     Special    10
# 124  Small  Non-organic       Niche  Mild     Special    11
# 127  Small      Organic  MainStream  Mild  MainStream    11
# 129  Small      Organic  MainStream  Mild  MainStream    10
# 130  Small      Organic  MainStream  Mild  MainStream    10

# %%
print("Organic :" ,attribute_item_sim('Organic', df_mild_small))
print("Brand :" ,attribute_item_sim('Brand', df_mild_small))
print("Flavor :" ,attribute_item_sim('Flavor', df_mild_small))
# In sub-section Mild_Small item-attribute = 1
# ==> There no significant attribute
# sub-section Mild_Small is a leaf node
# as we can see, there are two type of item, each with their attribute values
# Out:
# Organic : 1.0
# Brand : 1.0
# Flavor : 1.0

# %%
df_non_mild = df.loc[df['Mild'] == 'Non-mild']
df_non_mild
# Out:
#               Date_Time  Store_ID  User_ID Item_ID  Unit_sales Category  \
#
#
#        Size      Organic       Brand      Mild        Flavor  Week
# 2    Medium      Organic  MainStream  Non-mild       Special    13
# 4     Large  Non-organic  MainStream  Non-mild    MainStream    12
# 5    Medium      Organic  MainStream  Non-mild       Special    11
# 8     Large  Non-organic  MainStream  Non-mild    MainStream    10
# 9    Medium      Organic  MainStream  Non-mild       Special    11
# 10    Large  Non-organic  MainStream  Non-mild  Non-flavored    13
# 11    Small  Non-organic  MainStream  Non-mild       Special    12
# 16    Large  Non-organic  MainStream  Non-mild  Non-flavored    11
# 21    Large  Non-organic  MainStream  Non-mild    MainStream    12
# 24    Large  Non-organic  MainStream  Non-mild    MainStream    12
# 42    Small  Non-organic  MainStream  Non-mild       Special    13
# 43    Small  Non-organic  MainStream  Non-mild       Special    10
# 44    Large  Non-organic  MainStream  Non-mild    MainStream    13
# 47    Large  Non-organic  MainStream  Non-mild    MainStream    10
# 48    Large  Non-organic  MainStream  Non-mild  Non-flavored    11
# 49   Medium      Organic  MainStream  Non-mild       Special    13
# 52    Large  Non-organic  MainStream  Non-mild    MainStream    10
# 53    Small  Non-organic  MainStream  Non-mild       Special    13
# 55    Large  Non-organic  MainStream  Non-mild  Non-flavored    11
# 60   Medium      Organic  MainStream  Non-mild       Special    12
# 65   Medium      Organic  MainStream  Non-mild       Special    12
# 69   Medium      Organic  MainStream  Non-mild       Special    13
# 71    Large  Non-organic  MainStream  Non-mild    MainStream    10
# 73   Medium      Organic  MainStream  Non-mild       Special    12
# 74    Small  Non-organic  MainStream  Non-mild       Special    13
# 80    Large  Non-organic  MainStream  Non-mild    MainStream    11
# 82    Small  Non-organic  MainStream  Non-mild       Special    12
# 91    Small  Non-organic  MainStream  Non-mild       Special    10
# 96   Medium      Organic  MainStream  Non-mild       Special    10
# 97    Large  Non-organic  MainStream  Non-mild    MainStream    13
# 98    Large  Non-organic  MainStream  Non-mild    MainStream    11
# 101   Large  Non-organic  MainStream  Non-mild    MainStream    10
# 102   Large  Non-organic  MainStream  Non-mild    MainStream    13
# 103   Large  Non-organic  MainStream  Non-mild    MainStream    10
# 106   Large  Non-organic  MainStream  Non-mild    MainStream    13
# 109   Large  Non-organic  MainStream  Non-mild    MainStream    10
# 112   Small  Non-organic  MainStream  Non-mild       Special    10
# 113   Large  Non-organic  MainStream  Non-mild    MainStream    10
# 114   Large  Non-organic  MainStream  Non-mild    MainStream    10
# 115   Large  Non-organic  MainStream  Non-mild    MainStream    11
# 117  Medium      Organic  MainStream  Non-mild       Special    13
# 120   Large  Non-organic  MainStream  Non-mild    MainStream    10
# 126   Large  Non-organic  MainStream  Non-mild    MainStream    13

# %%
print("Size :" ,attribute_item_sim('Size', df_non_mild))
print("Brand :" ,attribute_item_sim('Brand', df_non_mild))
print("Organic :" ,attribute_item_sim('Organic', df_non_mild))
print("Flavor :" ,attribute_item_sim('Flavor', df_non_mild))
# Out:
# Size : 0.5052202305226957
# Brand : 1.0
# Organic : 0.4352731405679618
# Flavor : 0.46243958567570204

# %%
# In sub-section Non-mild, Item-Size similarity is max
# ==> Size is significant attribute
df_non_mild.groupby('Size')['Unit_sales'].sum()
# Out:
# Size
# Large     79
# Medium    34
# Small     19
# Name: Unit_sales, dtype: int64

# %%
df_non_mild_small = df_non_mild.loc[df_non_mild['Size'] == "Small"]
df_non_mild_small
# As we can see, every item in sub-section Non-mild_Small is the same > leaf node
# Out:
#               Date_Time  Store_ID  User_ID Item_ID  Unit_sales Category  \
# 11  2018-03-21 06:00:00         1        1   Yo002           1   Yogurt
# 42  2018-03-28 06:00:00         1        4   Yo002           3   Yogurt
# 43  2018-03-07 06:00:00         2        3   Yo002           4   Yogurt
# 53  2018-03-28 06:00:00         1        4   Yo002           1   Yogurt
# 74  2018-03-31 06:00:00         1       17   Yo002           2   Yogurt
# 82  2018-03-24 06:00:00         1       19   Yo002           2   Yogurt
# 91  2018-03-07 06:00:00         1       20   Yo002           5   Yogurt
# 112 2018-03-10 06:00:00         1       15   Yo002           1   Yogurt
#
#       Size      Organic       Brand      Mild   Flavor  Week
# 11   Small  Non-organic  MainStream  Non-mild  Special    12
# 42   Small  Non-organic  MainStream  Non-mild  Special    13
# 43   Small  Non-organic  MainStream  Non-mild  Special    10
# 53   Small  Non-organic  MainStream  Non-mild  Special    13
# 74   Small  Non-organic  MainStream  Non-mild  Special    13
# 82   Small  Non-organic  MainStream  Non-mild  Special    12
# 91   Small  Non-organic  MainStream  Non-mild  Special    10
# 112  Small  Non-organic  MainStream  Non-mild  Special    10

# %%
df_non_mild_medium = df_non_mild.loc[df_non_mild['Size'] == "Medium"]
df_non_mild_medium
# As we can see, every item in sub-section Non-mild_Medium is the same > leaf node
# Out:
#               Date_Time  Store_ID  User_ID Item_ID  Unit_sales Category  \
# 2   2018-03-28 06:00:00         1       20   Yo005           2   Yogurt
# 5   2018-03-14 06:00:00         1        1   Yo005           3   Yogurt
# 9   2018-03-17 06:00:00         1        3   Yo005           5   Yogurt
# 49  2018-03-31 06:00:00         1       17   Yo005           3   Yogurt
# 60  2018-03-21 06:00:00         1       17   Yo005           2   Yogurt
# 65  2018-03-24 06:00:00         1       19   Yo005           1   Yogurt
# 69  2018-03-31 06:00:00         1        9   Yo005           5   Yogurt
# 73  2018-03-21 06:00:00         1       10   Yo005           5   Yogurt
# 96  2018-03-07 06:00:00         1       17   Yo005           3   Yogurt
# 117 2018-03-28 06:00:00         1        6   Yo005           5   Yogurt
#
#        Size  Organic       Brand      Mild   Flavor  Week
# 2    Medium  Organic  MainStream  Non-mild  Special    13
# 5    Medium  Organic  MainStream  Non-mild  Special    11
# 9    Medium  Organic  MainStream  Non-mild  Special    11
# 49   Medium  Organic  MainStream  Non-mild  Special    13
# 60   Medium  Organic  MainStream  Non-mild  Special    12
# 65   Medium  Organic  MainStream  Non-mild  Special    12
# 69   Medium  Organic  MainStream  Non-mild  Special    13
# 73   Medium  Organic  MainStream  Non-mild  Special    12
# 96   Medium  Organic  MainStream  Non-mild  Special    10
# 117  Medium  Organic  MainStream  Non-mild  Special    13

# %%
df_non_mild_large = df_non_mild.loc[df_non_mild['Size'] == "Large"]
df_non_mild_large
# As we can see, every item in sub-section Non-mild_Large is the same > leaf node
# End of the tree
# Out:
#               Date_Time  Store_ID  User_ID Item_ID  Unit_sales Category  \
# 4   2018-03-24 06:00:00         1       15   Yo007           2   Yogurt
# 8   2018-03-07 06:00:00         2        8   Yo007           1   Yogurt
# 10  2018-03-28 06:00:00         1        4   Yo009           3   Yogurt
# 16  2018-03-17 06:00:00         2        7   Yo009           3   Yogurt
# 21  2018-03-24 06:00:00         1        4   Yo007           4   Yogurt
# 24  2018-03-21 06:00:00         1       16   Yo007           3   Yogurt
# 44  2018-03-31 06:00:00         1       19   Yo007           3   Yogurt
# 47  2018-03-10 06:00:00         1        1   Yo007           5   Yogurt
# 48  2018-03-17 06:00:00         1        1   Yo009           4   Yogurt
# 52  2018-03-10 06:00:00         1        5   Yo007           5   Yogurt
# 55  2018-03-14 06:00:00         1        4   Yo009           3   Yogurt
# 71  2018-03-07 06:00:00         1        2   Yo007           5   Yogurt
# 80  2018-03-14 06:00:00         1       13   Yo007           5   Yogurt
# 97  2018-03-28 06:00:00         1       18   Yo007           1   Yogurt
# 98  2018-03-17 06:00:00         1       20   Yo007           3   Yogurt
# 101 2018-03-10 06:00:00         1       10   Yo007           2   Yogurt
# 102 2018-03-28 06:00:00         1       11   Yo007           1   Yogurt
# 103 2018-03-10 06:00:00         1       18   Yo007           3   Yogurt
# 106 2018-03-28 06:00:00         1       16   Yo007           2   Yogurt
# 109 2018-03-10 06:00:00         1        2   Yo007           3   Yogurt
# 113 2018-03-07 06:00:00         1       16   Yo007           1   Yogurt
# 114 2018-03-10 06:00:00         1       14   Yo007           5   Yogurt
# 115 2018-03-14 06:00:00         1       13   Yo007           5   Yogurt
# 120 2018-03-10 06:00:00         1       19   Yo007           2   Yogurt
# 126 2018-03-31 06:00:00         1        8   Yo007           5   Yogurt
#
#       Size      Organic       Brand      Mild        Flavor  Week
# 4    Large  Non-organic  MainStream  Non-mild    MainStream    12
# 8    Large  Non-organic  MainStream  Non-mild    MainStream    10
# 10   Large  Non-organic  MainStream  Non-mild  Non-flavored    13
# 16   Large  Non-organic  MainStream  Non-mild  Non-flavored    11
# 21   Large  Non-organic  MainStream  Non-mild    MainStream    12
# 24   Large  Non-organic  MainStream  Non-mild    MainStream    12
# 44   Large  Non-organic  MainStream  Non-mild    MainStream    13
# 47   Large  Non-organic  MainStream  Non-mild    MainStream    10
# 48   Large  Non-organic  MainStream  Non-mild  Non-flavored    11
# 52   Large  Non-organic  MainStream  Non-mild    MainStream    10
# 55   Large  Non-organic  MainStream  Non-mild  Non-flavored    11
# 71   Large  Non-organic  MainStream  Non-mild    MainStream    10
# 80   Large  Non-organic  MainStream  Non-mild    MainStream    11
# 97   Large  Non-organic  MainStream  Non-mild    MainStream    13
# 98   Large  Non-organic  MainStream  Non-mild    MainStream    11
# 101  Large  Non-organic  MainStream  Non-mild    MainStream    10
# 102  Large  Non-organic  MainStream  Non-mild    MainStream    13
# 103  Large  Non-organic  MainStream  Non-mild    MainStream    10
# 106  Large  Non-organic  MainStream  Non-mild    MainStream    13
# 109  Large  Non-organic  MainStream  Non-mild    MainStream    10
# 113  Large  Non-organic  MainStream  Non-mild    MainStream    10
# 114  Large  Non-organic  MainStream  Non-mild    MainStream    10
# 115  Large  Non-organic  MainStream  Non-mild    MainStream    11
# 120  Large  Non-organic  MainStream  Non-mild    MainStream    10
# 126  Large  Non-organic  MainStream  Non-mild    MainStream    13

# %%
print("Brand :" ,attribute_item_sim('Brand', df_non_mild_large))
print("Organic :" ,attribute_item_sim('Organic', df_non_mild_large))
print("Flavor :" ,attribute_item_sim('Flavor', df_non_mild_large))
# Out:
# Brand : 1.0
# Organic : 1.0
# Flavor : 0.9999999999999999
